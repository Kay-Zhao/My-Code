# %% [markdown]
# # 标题
# # 一级标题
# ## 二级标题
# ### 三级标题
# #### 四级标题
# ##### 五级标题
# ###### 六级标题

# %% [markdown]
# **加粗**
# _斜体_
# ~~删除线~~
# `高亮`

# %% [markdown]
# >引用
# >>二层引用
# >>>三层引用

# %% [markdown]
# * 第一
# + 第二
# - 第三
# 1. 第一
# 2. 第二

# %% [markdown]
# 网站链接: https://www.bing.com
# 网站名称: [必应](https://www.bing.com)

# %% [markdown]
# ***
# 水平线,利用水平线分割
# ***

# %% [markdown]
# ```python
# string = '我是代码'
# print(string)
# ```

# %% [markdown]
# 我是`print('行内代码')`
# 这个和高亮没什么区别

# %% [markdown]
# 在行结尾**空两格**再回车即可换行
# end

# %% [markdown]
# 插入图片
# 网络图片
# <img src='https://i1.hdslb.com/bfs/archive/2191d0f448b0bcbeef08e686acc942698cb69150.jpg@256w_144h_1c.avif'>
# 本地图片直接复制进来![1.jpg](attachment:1.jpg)

# %% [markdown]
# 数学公式Latex代码
# 正文中显示$ \sqrt{x^2+y^2} $
# 单独一行显示$$ \sqrt{x^2+y^2} $$

# %% [markdown]
# 一个脚注[^1]
#
# [^1]:https://www.bing.com

# %% [markdown]
# 进阶
# <img src=https://pic1.zhimg.com/80/v2-a4ccab7929a38518bb5eb943d0f6d904_720w.webp>

# %% [markdown]
# [交互式控件](https://blog.csdn.net/liuqixuan1994/article/details/86708381)
# 文本框，滑动条……

# %%
import ipywidgets as widgets	# 控件库
from IPython.display import display	# 显示控件的方法
text = widgets.Text()
display(text)

def print_value(sender):
    print(sender.value)

text.on_submit(print_value)	# 回车以提交内容
# Out:
# Text(value='')
# C:\Users\Kay\AppData\Local\Temp\ipykernel_2940\4064487600.py:9: DeprecationWarning: on_submit is deprecated. Instead, set the .continuous_update attribute to False and observe the value changing with: mywidget.observe(callback, 'value').
#   text.on_submit(print_value)	# 回车以提交内容
# hhh
# hhh
# hhh
# hhh
# hhh
# hhh
# hhh
# hhh
# hhh
# hhh

# %%
btn = widgets.Button(description = "OK", tooltip = 'this is a button')
def btn_click(sender):
	print('Button %s clicked!' % sender.description)
btn.on_click(btn_click)
display(btn)
# Out:
# Button(description='OK', style=ButtonStyle(), tooltip='this is a button')
# Button OK clicked!
# Button OK clicked!
# Button OK clicked!
# Button OK clicked!
# Button OK clicked!
# Button OK clicked!
